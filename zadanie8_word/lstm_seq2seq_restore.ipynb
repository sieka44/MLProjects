# %% [markdown]
# # Restore a character-level sequence to sequence model from to generate predictions.
#
# Source:
# https://keras.io/examples/lstm_seq2seq_restore/
#
# This script loads the s2s.h5 model saved by lstm_seq2seq.py and generates sequences from it. It assumes that no changes have been made (for example: latent_dim is unchanged, and the input data and model architecture are unchanged).

# %% [markdown]
# ### Data download
#
# Lots of neat sentence pairs datasets. http://www.manythings.org/anki/

# %%
from __future__ import print_function

from keras.models import Model, load_model
from keras.layers import Input
import numpy as np

batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'lang_pairs/pol.txt'

# %% [markdown]
# Let's read the sentences (input = English, target = Polish),
# and extract the character sets for each language.
#
# Target sequences get additional "start sequence" and "end sequence" characters.

# %%
# Vectorize the data.  We use the same approach as the training script.
# NOTE: the data must be identical, in order for the character -> integer
# mappings to be consistent.
# We omit encoding target_texts since they are not needed.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, licence = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 74
# Number of unique output tokens: 92
# Max sequence length for inputs: 22
# Max sequence length for outputs: 58

# %% [markdown]
# Make character-to-index dictionaries
# and prepare one-hot-encoding of the whole training input data.
# Note that the sequences are zero-(post)padded to have all equal lengths.

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')

for i, input_text in enumerate(input_texts):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.

# %%
# Restore the model and construct the encoder and decoder.
model = load_model('s2s.h5')

encoder_inputs = model.input[0]   # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output   # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]   # input_2
decoder_state_input_h = Input(shape=(latent_dim,), name='input_3')
decoder_state_input_c = Input(shape=(latent_dim,), name='input_4')
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
# Decodes an input sequence.  Future work should support beam search.
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index+1000: seq_index + 1001]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index+1000])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: You're weak.
# Decoded sentence: Jesteś wymagający.
#
# -
# Input sentence: Abandon ship!
# Decoded sentence: Czygo ice ma swojega?
#
# -
# Input sentence: Am I invited?
# Decoded sentence: Czy una ras Tom?
#
# -
# Input sentence: Anybody here?
# Decoded sentence: Kladzemy zamychałe?
#
# -
# Input sentence: Anybody hurt?
# Decoded sentence: Kladzemy zamychałe?
#
# -
# Input sentence: Anything new?
# Decoded sentence: Każ kontynumiżymy?
#
# -
# Input sentence: Are they new?
# Decoded sentence: Są siestni?
#
# -
# Input sentence: Are they new?
# Decoded sentence: Są siestni?
#
# -
# Input sentence: Are we alone?
# Decoded sentence: Jesteś nauczacien?
#
# -
# Input sentence: Are we ready?
# Decoded sentence: Już zasłaci?
#
# -
# Input sentence: Are you busy?
# Decoded sentence: Jesteś zapisany?
#
# -
# Input sentence: Are you cold?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you done?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you done?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you done?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you lost?
# Decoded sentence: Jesteś zaungażonany?
#
# -
# Input sentence: Are you nuts?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you nuts?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you nuts?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you safe?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you sick?
# Decoded sentence: Jesteś zaangażowany?
#
# -
# Input sentence: Are you sure?
# Decoded sentence: Jesteś rozważny?
#
# -
# Input sentence: Are you sure?
# Decoded sentence: Jesteś rozważny?
#
# -
# Input sentence: Be realistic!
# Decoded sentence: Bądź bardziej amochony.
#
# -
# Input sentence: Can Tom cook?
# Decoded sentence: Czy Tom może do ciebie dołączyć?
#
# -
# Input sentence: Can Tom cook?
# Decoded sentence: Czy Tom może do ciebie dołączyć?
#
# -
# Input sentence: Can Tom sing?
# Decoded sentence: Czy Tom może to zrobić?
#
# -
# Input sentence: Can Tom sing?
# Decoded sentence: Czy Tom może to zrobić?
#
# -
# Input sentence: Can Tom walk?
# Decoded sentence: Czy Tom umie godzić spować?
#
# -
# Input sentence: Can we do it?
# Decoded sentence: Czy możemy wziąć Toma?
#
# -
# Input sentence: Can we leave?
# Decoded sentence: Możesz mi potrzeboććć?
#
# -
# Input sentence: Can we start?
# Decoded sentence: Możemy się tutaj?
#
# -
# Input sentence: Can you come?
# Decoded sentence: Potrafisz go zatabić?
#
# -
# Input sentence: Can you hear?
# Decoded sentence: Możesz to narzykować?
#
# -
# Input sentence: Can you help?
# Decoded sentence: Potrafisz sprzejdzint?
#
# -
# Input sentence: Can you move?
# Decoded sentence: Czy kontas było?
#
# -
# Input sentence: Can you stay?
# Decoded sentence: Możesz przytłość dom?
#
# -
# Input sentence: Can you wait?
# Decoded sentence: Możesz pomóc Tomowi?
#
# -
# Input sentence: Check it out!
# Decoded sentence: Dobądzies lech, Toma.
#
# -
# Input sentence: Come help me.
# Decoded sentence: Chodź tutaj.
#
# -
# Input sentence: Come outside.
# Decoded sentence: Przyjdź tu robiję.
#
# -
# Input sentence: Come quickly!
# Decoded sentence: Prawie jest tutaj czasa?
#
# -
# Input sentence: Come quickly.
# Decoded sentence: Przyjdź też jutro!
#
# -
# Input sentence: Come with us.
# Decoded sentence: Chodź tutaj derwaj.
#
# -
# Input sentence: Deal with it.
# Decoded sentence: Poranać mi problema.
#
# -
# Input sentence: Deal with it.
# Decoded sentence: Poranać mi problema.
#
# -
# Input sentence: Describe Tom.
# Decoded sentence: Opiów ją okońcuune.
#
# -
# Input sentence: Did Tom call?
# Decoded sentence: Czy Tom nie umieła?
#
# -
# Input sentence: Did Tom come?
# Decoded sentence: Czy Tom nie wiadła?
#
# -
# Input sentence: Did Tom stay?
# Decoded sentence: Czytoń to tak zrociolił?
#
# -
# Input sentence: Did you call?
# Decoded sentence: Ktołeś początkę?
#
# -
# Input sentence: Did you sign?
# Decoded sentence: Kupiesz się Tom?
#
# -
# Input sentence: Did you vote?
# Decoded sentence: Kupiesz się Tom?
#
# -
# Input sentence: Do I look OK?
# Decoded sentence: Wyblam wstowek?
#
# -
# Input sentence: Do I look OK?
# Decoded sentence: Wyblam wstowek?
#
# -
# Input sentence: Does it hurt?
# Decoded sentence: Czy to w damo?
#
# -
# Input sentence: Don't be sad.
# Decoded sentence: Nie bądź taki skromny.
#
# -
# Input sentence: Don't bother.
# Decoded sentence: Nie kłam mi.
#
# -
# Input sentence: Don't forget.
# Decoded sentence: Nie przeprosujemy.
#
# -
# Input sentence: Don't hit me.
# Decoded sentence: Nie rób tego dla mnie.
#
# -
# Input sentence: Don't hit me.
# Decoded sentence: Nie rób tego dla mnie.
#
# -
# Input sentence: Don't litter!
# Decoded sentence: Nie kłam się.
#
# -
# Input sentence: Don't slouch.
# Decoded sentence: Nie poszuj się.
#
# -
# Input sentence: Drive safely.
# Decoded sentence: Jeź za wieżyjącecen.
#
# -
# Input sentence: Drive slowly.
# Decoded sentence: Nakorz nosty nie skończyła.
#
# -
# Input sentence: Examine this.
# Decoded sentence: zdzieja ma się pespiej.
#
# -
# Input sentence: Fear nothing.
# Decoded sentence: Nie pałas miłok.
#
# -
# Input sentence: Fear nothing.
# Decoded sentence: Nie pałas miłok.
#
# -
# Input sentence: Fear nothing.
# Decoded sentence: Nie pałas miłok.
#
# -
# Input sentence: Ghosts exist.
# Decoded sentence: Odwóc przerabie się z Tomem.
#
# -
# Input sentence: Give me that.
# Decoded sentence: Daj mi twoje piennątry.
#
# -
# Input sentence: Go back home.
# Decoded sentence: Wracaj do domu.
#
# -
# Input sentence: Good morning.
# Decoded sentence: Dzteń jest już na piewaczóc.
#
# -
# Input sentence: Grab it, Tom.
# Decoded sentence: Aweno nie potrafi paznać.
#
# -
# Input sentence: Hand it over.
# Decoded sentence: Oddaj jeszcze naszczegd.
#
# -
# Input sentence: Hand it over.
# Decoded sentence: Oddaj jeszcze naszczegd.
#
# -
# Input sentence: Hand it over.
# Decoded sentence: Oddaj jeszcze naszczegd.
#
# -
# Input sentence: Happy Easter!
# Decoded sentence: Wszystko, czekoniniem?
#
# -
# Input sentence: Have a donut.
# Decoded sentence: Zaczeraj jest namiema.
#
# -
# Input sentence: He has a dog.
# Decoded sentence: On stracił bratę.
#
# -
# Input sentence: He has a dog.
# Decoded sentence: On stracił bratę.
#
# -
# Input sentence: He is French.
# Decoded sentence: On zaważa jest bałdy.
#
# -
# Input sentence: He loves her.
# Decoded sentence: On napisał raport.
#
# -
# Input sentence: He loves you.
# Decoded sentence: On napisał raport.
#
# -
# Input sentence: He was brave.
# Decoded sentence: Był cierplewaci.
#
# -
# Input sentence: He's a bigot.
# Decoded sentence: On jest nachmystącki.
#
# -
# Input sentence: He's jealous.
# Decoded sentence: On jest moją sąostro.
#
# -
# Input sentence: He's too old.
# Decoded sentence: On zerdzi ni duwiło.
#
# -
# Input sentence: Hey, wait up!
# Decoded sentence: Hej, co się stało?
#
# -
# Input sentence: Hey, wait up!
# Decoded sentence: Hej, co się stało?
#
# -
# Input sentence: How horrible!
# Decoded sentence: Jak się mastowałoś?
#
# -
# Input sentence: How horrible!
# Decoded sentence: Jak się mastowałoś?
#
# -
# Input sentence: How romantic!
# Decoded sentence: Jak to zabawny?
#
# -
# Input sentence: I am Chinese.
# Decoded sentence: Jestem prawie gotów.
#
# -
# Input sentence: I am ashamed.
# Decoded sentence: Jestem dziska ją pienie.
#
# -
# Input sentence: I am at home.
# Decoded sentence: Jestem sicnym o cemiem.
#
# -
# Input sentence: I am curious.
# Decoded sentence: Bardzo mi przykonił.
#
# -
# Input sentence: I am married.
# Decoded sentence: Jestem dobre wiodny.
#
# -
# Input sentence: I can't move.
# Decoded sentence: Nie mogę się skontaktować z Tomem.
#
# -
# Input sentence: I can't swim.
# Decoded sentence: Nie mogę zamkcej tomko nużery.
